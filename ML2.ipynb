# %%
 import seaborn as sb

# %%
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
print(df.head())
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
import pandas as pd
df = pd.read_csv("/home/user/ML LAB/Car_sales.csv")
num_attributes = df.shape[1]
print("Number of attributes:", num_attributes)
# Out:
# Number of attributes: 15

# %%
# 1.Read top five values
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
print(df.head())
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
# 2.Print dataframe info_data types of each column
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
# print(df.info())
print(df.dtypes)
# Out:
# Manufacturer            object
# Model                   object
# Sales in thousands     float64
# 4-year resale value     object
# Vehicle type            object
# Price in thousands      object
# Engine size             object
# Horsepower              object
# Wheelbase               object
# Width                   object
# Length                  object
# Curb weight             object
# Fuel capacity           object
# Fuel efficiency         object
# Latest Launch           object
# dtype: object

# %%
# 3.Print number of rows and columns
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
rows, cols = df.shape

print(f"Number of Rows: {rows}")
print(f"Number of Columns: {cols}")
# Out:
# Number of Rows: 157
# Number of Columns: 15

# %%
# 4.Drop duplicate rows_if any
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
# Drop duplicate rows
df = df.drop_duplicates()

# Print updated DataFrame
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
# 5.Print number of rows and columns after dropping duplicates
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
# Create a new DataFrame without duplicates
df_no_duplicates = df.drop_duplicates()

# Get number of rows and columns after dropping duplicates
rows, cols = df_no_duplicates.shape

# Print updated count
print(f"Number of Rows after dropping duplicates: {rows}")
print(f"Number of Columns: {cols}")
# Out:
# Number of Rows after dropping duplicates: 157
# Number of Columns: 15

# %%
# 6. Print summary statistics for numerical variables
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
print(df.describe())
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
# 7.Print number of missing values in each column
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
# Print number of missing values per column
print(df.isna().sum())
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
# 8. Drop the column with most missing values
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
# Identify the column with the most missing values
col_with_most_missing = df.isna().sum().idxmax()

# Drop that column
df = df.drop(columns=[col_with_most_missing])

# Print the updated DataFrame
print(f"Column with most missing values: {col_with_most_missing}")
# Out:
# Column with most missing values: Manufacturer

# %%
# 9. Drop the rows with categorical missing values
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
# Select categorical columns (object data type)
categorical_columns = df.select_dtypes(include=['object']).columns

# Drop rows with missing values in categorical columns
df_cleaned = df.dropna(subset=categorical_columns)

# Print the cleaned DataFrame
df_cleaned.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
# 10.Import the rows with numerical missing values
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")
# Select numerical columns (int64, float64 types)
numerical_columns = df.select_dtypes(include=['number']).columns

# Filter rows with missing values in numerical columns
rows_with_missing_numerical = df[df[numerical_columns].isna().any(axis=1)]

# Print the rows with missing numerical values
print(rows_with_missing_numerical)
# Out:
# Empty DataFrame
# Columns: [Manufacturer, Model, Sales in thousands, 4-year resale value, Vehicle type, Price in thousands, Engine size, Horsepower, Wheelbase, Width, Length, Curb weight, Fuel capacity, Fuel efficiency, Latest Launch]
# Index: []

# %%
#11.Sort the data w.r.t price_find the details of the most and the least expensive cars
import pandas as pd
df=pd.read_csv("/home/user/ML LAB/Car_sales.csv")

# Sort the data by price (ascending)
df_sorted = df.sort_values(by='Price in thousands', ascending=True)

# Find the least expensive car
least_expensive_car = df_sorted.iloc[0]

# Find the most expensive car
most_expensive_car = df_sorted.iloc[-1]

# Print the results
print("Details of the Least Expensive Car:")
print(least_expensive_car)

print("\nDetails of the Most Expensive Car:")
print(most_expensive_car)
# Out:
# Details of the Least Expensive Car:
# Manufacturer               Acura
# Model                  CL
# Sales in thousands                14.114
# 4-year resale value               18.225
# Vehicle type                   Passenger
# Price in thousands                     .
# Engine size                          3.2
# Horsepower                           225
# Wheelbase                          106.9
# Width                               70.6
# Length                               192
# Curb weight                         3.47
# Fuel capacity                       17.2
# Fuel efficiency                       26
# Latest Launch                   1-Apr-14
# Name: 2, dtype: object
#
# Details of the Most Expensive Car:
# Manufacturer               Hyundai
# Model                  Accent
# Sales in thousands                41.184
# 4-year resale value                 5.86
# Vehicle type                   Passenger
# Price in thousands                 9.699
# ...

# %%
#12. Write a function to find min and max values of any column
import pandas as pd

def find_min_max(df, column_name):
    """
    Function to find the minimum and maximum values of a specified column in a DataFrame.
    
    Parameters:
    df (pd.DataFrame): The input DataFrame.
    column_name (str): The column name to find min and max values for.
    
    Returns:
    tuple: (min_value, max_value)
    """
    if column_name not in df.columns:
        return f"Column '{column_name}' not found in DataFrame"
    
    min_value = df[column_name].min()
    max_value = df[column_name].max()
    
    return min_value, max_value

# Example Usage:
df = pd.read_csv("/home/user/ML LAB/Car_sales.csv")  # Load your dataset

# Find

# %%
#13. Call the above function to find min max of horse power, length, fuel efficiency
# Load dataset
df = pd.read_csv("/home/user/ML LAB/Car_sales.csv")  # Replace with the actual file path

# Find min and max values for Horsepower, Length, and Fuel Efficiency
min_hp, max_hp = find_min_max(df, 'Horsepower')
min_length, max_length = find_min_max(df, 'Length')
min_fe, max_fe = find_min_max(df, 'Fuel efficiency')

# Print results
print(f"Horsepower - Min: {min_hp}, Max: {max_hp}")
print(f"Length - Min: {min_length}, Max: {max_length}")
print(f"Fuel Efficiency - Min: {min_fe}, Max: {max_fe}")
# Out:
# Horsepower - Min: ., Max: 92
# Length - Min: ., Max: 224.5
# Fuel Efficiency - Min: ., Max: 45

# %%
#14. Plot histogram of continuous numerical variable : price,sales,hoursepower,fuelefficiency
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)


# Load dataset
df = pd.read_csv("/home/user/ML LAB/Car_sales.csv")  # Replace with actual file path
df.replace([np.inf, -np.inf], np.nan, inplace=True)
# List of continuous numerical columns
columns = ["Price in thousands", "Sales in thousands", "Horsepower", "Fuel efficiency"]

# Create histograms
plt.figure(figsize=(12, 8))

for i, col in enumerate(columns, 1):
    plt.subplot(2, 2, i)  # 2 rows, 2 columns
    sns.histplot(df[col], bins=30, kde=True)  # KDE=True adds a density curve
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# without desnity curve -kde
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')

# List of continuous numerical variables
columns = ["Price in thousands", "Sales in thousands", "Horsepower", "Fuel efficiency"]

# Plotting histograms
plt.figure(figsize=(12, 8))

for i, col in enumerate(columns):
    plt.subplot(2, 2, i + 1)
    plt.hist(df[col].dropna(), bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# 15. Probability density distribution of continuous numerical variable-length
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Convert and drop NaNs
df['length'] = pd.to_numeric(df['Length'], errors='coerce')
df = df.dropna(subset=['length'])

# Plot PDF using KDE
sns.histplot(data=df, x='Length', kde=True, bins=20, color='orange')
plt.title("Probability Density Distribution of Length")
plt.xlabel("Length")
plt.ylabel("Density")
plt.show()

# %%
# 16. Count by category –group by manufacture
import pandas as pd
df=pd.read_csv('/home/user/ML LAB/Car_sales.csv')
#print(df.columns)
manufacturer_counts = df.groupby('Manufacturer').size().reset_index(name='count')
print(manufacturer_counts)
# Out:
#      Manufacturer  count
# 0   Acura              4
# 1   Audi               3
# 2   BMW                3
# 3   Buick              4
# 4   Cadillac           5
# 5   Chevrolet          9
# 6   Chrysler           7
# 7   Dodge             11
# 8   Ford              11
# 9   Honda              5
# 10  Hyundai            3
# 11  Infiniti           1
# 12  Jaguar             1
# 13  Jeep               3
# 14  Lexus              6
# 15  Lincoln            3
# 16  Mercedes-Benz      9
# 17  Mercury            6
# 18  Mitsubishi         7
# 19  Nissan             7
# 20  Oldsmobile         6
# 21  Plymouth           4
# 22  Pontiac            6
# 23  Porsche            3
# 24  Saab               2
# 25  Saturn             5
# 26  Subaru             2
# 27  Toyota             9
# 28  Volkswagen         6
# 29  Volvo              6

# %%
# 17. Select all numerical variables
import pandas as pd
df=pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df=df.select_dtypes(include=['number'])
print(df)
# Out:
#      Sales in thousands
# 0                16.919
# 1                39.384
# 2                14.114
# 3                 8.588
# 4                20.397
# ..                  ...
# 152               3.545
# 153              15.245
# 154              17.531
# 155               3.493
# 156              18.969
#
# [157 rows x 1 columns]

# %%
# 18.Print correlation coefficient value of price and sales
import pandas as pd
df=pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors='coerce')
df['Sales in thousands']=pd.to_numeric(df['Sales in thousands'],errors='coerce')
df_clean=df.dropna(subset=['Price in thousands','Sales in thousands'])
correlation = df_clean['Price in thousands'].corr(df_clean['Sales in thousands'])
print(f"Correlation coefficient between price and sales: {correlation:.4f}")
# Out:
# Correlation coefficient between price and sales: -0.3047

# %%
#19. Plot correlation of price and sales using scatterplot
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df['Price in thousands']=pd.to_numeric(df['Price in thousands'],errors='coerce')
df['Sales in thousands']=pd.to_numeric(df['Sales in thousands'],errors='coerce')
df_clean=df.dropna(subset=['Price in thousands','Sales in thousands'])

plt.figure(figsize=(8,6))
sns.scatterplot(data=df_clean,x='Price in thousands',y='Sales in thousands',color='royalblue')
plt.title("scatterplot of price vs sales")
plt.xlabel("price")
plt.ylabel("sales")
plt.grid(True)
plt.show()

# %%
#20.Pair plot
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
num_df.replace([np.inf, -np.inf], np.nan, inplace=True)
num_df.dropna(inplace=True)
# num_df = df.select_dtypes(include=['number'])
sns.pairplot(num_df)
plt.suptitle("Pair Plot of Numerical Variables", y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4 import matplotlib.pyplot as plt
#       5 df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
# ----> 6 num_df.replace([np.inf, -np.inf], np.nan, inplace=True)
#       7 num_df.dropna(inplace=True)
#       8 # num_df = df.select_dtypes(include=['number'])
#
# NameError: name 'num_df' is not defined

# %%
#21. Boxplot of sales of different manufacturer
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df['Sales in thousands']=pd.to_numeric(df['Sales in thousands'],errors='coerce')
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_clean, x='Manufacturer', y='Sales in thousands', palette='Set2')
plt.title("Boxplot of Sales by Manufacturer")
plt.xlabel("Manufacturer")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#23 Boxplot of other numerical variables w.r.t manufacture
num_cols = df.select_dtypes(include=['number']).columns
df_clean = df.dropna(subset=['Manufacturer'] + list(num_cols))
for col in num_cols:
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=df_clean, x='Manufacturer', y=col, palette='pastel')
    plt.title(f"Boxplot of {col.capitalize()} by Manufacturer")
    plt.xlabel("Manufacturer")
    plt.ylabel(col.capitalize())
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
#23. Divide the data into input and output y=sales in thousand, x=all other variables
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df['Sales in thousands']=pd.to_numeric(df['Sales in thousands'],errors='coerce')
df_clean=df.dropna()
y=df_clean['Sales in thousands']
x=df_clean.drop('Sales in thousands',axis=1)
print("Input shape (X):", x.shape)
print("Output shape (y):", y.shape)
# Out:
# Input shape (X): (157, 14)
# Output shape (y): (157,)

# %%
#24. Encode other categorical variables using label encoder
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df_clean=df.dropna()
cat_cols=df.select_dtypes(include=['object']).columns
le=LabelEncoder()
for col in cat_cols:
    df[col]=le.fit_transform(df[col])

print("Encoded DataFrame:")
df.head()
# Out:
# Encoded DataFrame:
#    Manufacturer  Model  Sales in thousands  4-year resale value  Vehicle type  \
# 0             0     79              16.919                   53             1
# 1             0    143              39.384                   70             1
# 2             0     25              14.114                   63             1
# 3             0    115               8.588                   87             1
# 4             1      8              20.397                   78             1
#
#    Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0                  59            4          17          5      9      15
# 1                 102           16          50         36     32      83
# 2                   0           16          50         29     35      80
# 3                 130           19          44         56     40      97
# 4                  77            4          22          9     16      34
#
# ...

# %%
#25. Encode categorical variable vehicle type using one-hot encoder
import pandas as pd
df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df.dropna(subset=['Vehicle type'])
df_encoded=pd.get_dummies(df,columns=['Vehicle type'])
df_encoded.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Price in thousands Engine size Horsepower Wheelbase Width Length  \
# 0               21.5         1.8        140     101.2  67.3  172.4
# 1               28.4         3.2        225     108.1  70.3  192.9
# 2                  .         3.2        225     106.9  70.6    192
# 3                 42         3.5        210     114.6  71.4  196.6
# 4              23.99         1.8        150     102.6  68.2    178
#
#   Curb weight Fuel capacity Fuel efficiency Latest Launch  Vehicle type_Car  \
# ...

# %%
#26.Split the data set into train and test set 70% train set 10% test set
from sklearn.model_selection import train_test_split
import pandas as pd
df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df.dropna()
x = df.drop('Sales in thousands', axis=1)
y = df['Sales in thousands']
x_80,x_unused,y_80,y_unused=train_test_split(x,y,test_size=0.20,random_state=42)
x_train,x_test,y_train,y_test=train_test_split(x_80,y_80,test_size=0.125,random_state=42)
print("Train set size:", x_train.shape)
print("Test set size:", x_test.shape)
# Out:
# Train set size: (109, 14)
# Test set size: (16, 14)

# %%
#27. Apply feature scaling on numerical variables
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('/home/user/ML LAB/Car_sales.csv')
df = df.dropna()

x = df.drop('Sales in thousands', axis=1)
y = df['Sales in thousands']

x_80, x_unused, y_80, y_unused = train_test_split(x, y, test_size=0.20, random_state=42)
x_train, x_test, y_train, y_test = train_test_split(x_80, y_80, test_size=0.125, random_state=42)

# Encode all categorical features together using OrdinalEncoder
cat_cols = x_train.select_dtypes(include=['object']).columns

encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)  # handles unseen categories
x_train[cat_cols] = encoder.fit_transform(x_train[cat_cols])
x_test[cat_cols] = encoder.transform(x_test[cat_cols])

# Now scale numerical features
num_cols = x_train.select_dtypes(include=['float64', 'int64']).columns

scaler = StandardScaler()
x_train.loc[:, num_cols] = scaler.fit_transform(x_train[num_cols])
x_test.loc[:, num_cols] = scaler.transform(x_test[num_cols])

x_train.head()
# Out:
#      Manufacturer     Model  4-year resale value  Vehicle type  \
# 78       0.054018  0.462150            -1.208431     -1.786703
# 48      -0.666958 -0.921937             1.602758      0.559690
# 148      1.616132 -1.115066             0.308131      0.559690
# 116      0.774994  1.620920            -0.727570     -1.786703
# 85       0.414506  0.333398            -0.061762     -1.786703
#
#      Price in thousands  Engine size  Horsepower  Wheelbase     Width  \
# 78             1.344233     2.124938    1.494044   0.982617  1.898766
# 48            -0.887057    -0.434380   -0.027926  -0.606786 -0.579863
# 148           -0.369657    -1.003117   -1.549896   1.751683 -1.312184
# 116           -0.628357    -0.576564   -0.557307   0.469906  1.673436
# 85             0.147744     0.134358    0.038247  -0.401702 -1.312184
#
#        Length  Curb weight  Fuel capacity  Fuel efficiency  Latest Launch
# 78   1.479236     1.738351       1.884085        -2.004266      -0.298869
# ...
